# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df=df.iloc[:,2:]

# %%
df.head(10)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0
# 5   27            58000          0
# 6   27            84000          0
# 7   32           150000          1
# 8   25            33000          0
# 9   35            65000          0

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Purchased', axis=1),
                                                    df['Purchased'],
                                                    test_size=0.3,
                                                    random_state=121)

X_train.shape, X_test.shape
# Out:
# ((280, 2), (120, 2))

# %%
X_train
# Out:
#      Age  EstimatedSalary
# 102   32            86000
# 201   49            74000
# 167   35            71000
# 371   60            83000
# 151   41            45000
# ..   ...              ...
# 180   26            16000
# 65    24            58000
# 95    35            44000
# 264   48            90000
# 322   41            52000
#
# [280 rows x 2 columns]

# %%
X_train.describe()
# Out:
#               Age  EstimatedSalary
# count  280.000000       280.000000
# mean    37.785714     69107.142857
# std     10.609244     32961.734397
# min     18.000000     15000.000000
# 25%     29.000000     44000.000000
# 50%     37.000000     67000.000000
# 75%     46.000000     86000.000000
# max     60.000000    150000.000000

# %%
X_test
# Out:
#      Age  EstimatedSalary
# 215   60           108000
# 200   35            39000
# 268   47           144000
# 143   30            89000
# 37    30            49000
# ..   ...              ...
# 357   41            72000
# 56    23            48000
# 395   46            41000
# 253   37           146000
# 69    31            68000
#
# [120 rows x 2 columns]

# %%
X_test.describe()
# Out:
#               Age  EstimatedSalary
# count  120.000000       120.000000
# mean    37.350000     71225.000000
# std     10.219153     36710.876391
# min     18.000000     15000.000000
# 25%     30.000000     41000.000000
# 50%     36.000000     71500.000000
# 75%     46.000000     89000.000000
# max     60.000000    148000.000000

# %% [markdown]
# # StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
scaler.mean_
# Out:
# array([3.77857143e+01, 6.91071429e+04])

# %%
X_train_scaled
# Out:
# array([[-0.54632295,  0.51341667],
#        [ 1.05892225,  0.14870631],
#        [-0.26304438,  0.05752872],
#        [ 2.09761032,  0.42223908],
#        [ 0.30351275, -0.73267707],
#        [ 1.34220082,  2.09382825],
#        [ 1.43662701, -1.0669949 ],
#        [ 1.34220082, -1.4620978 ],
#        [ 1.90875795,  0.78694945],
#        [ 0.96449606,  1.51637017],
#        [-0.45189676, -1.15817249],
#        [-0.35747057,  0.08792125],
#        [ 1.05892225, -1.00620984],
#        [-1.20730626,  0.33106149],
#        [-0.82960151,  0.17909884],
#        [ 0.02023418, -0.12482646],
#        [-0.26304438,  1.18205234],
#        [ 1.90875795, -0.67189201],
#        [ 0.96449606,  0.81734198],
#        [ 0.77564369, -1.12777996],
#        [-1.01845389,  0.81734198],
#        [-0.45189676, -0.00325634],
#        [ 2.09761032, -0.82385466],
#        [ 0.39793894, -0.4591443 ],
#        [ 1.43662701,  0.39184655],
#        [-0.26304438, -0.27678912],
#        [ 0.11466037,  0.2398839 ],
#        [ 0.96449606,  1.97225813],
#        [-0.73517532,  0.5438092 ],
#        [ 2.09761032, -0.70228454],
#        [ 0.02023418, -0.24639659],
#        [ 0.39793894,  0.02713619],
#        [ 0.20908656,  1.15165981],
#        [-0.54632295,  2.45853861],
#        [ 0.87006988,  1.09087475],
#        [-1.01845389, -0.33757418],
#        [ 0.30351275,  0.08792125],
#        [-1.30173245,  0.60459426],
#        [ 0.20908656,  0.17909884],
#        [ 2.09761032, -0.82385466],
#        [ 2.00318413, -1.21895755],
#        [ 1.34220082,  1.36440752],
#        [ 1.53105319,  1.06048222],
#        [-0.074192  , -0.36796671],
#        [ 0.20908656,  0.17909884],
#        [ 0.87006988, -0.58071442],
#        [-1.30173245, -1.40131274],
#        [ 0.20908656,  0.27027643],
#        [-0.074192  ,  0.08792125],
#        [-0.074192  ,  0.05752872],
#        [-1.6794372 , -1.40131274],
#        [-0.16861819, -0.58071442],
#        [-0.074192  ,  0.02713619],
#        [-0.35747057,  1.39480005],
#        [-0.73517532,  1.15165981],
#        [ 0.11466037, -0.24639659],
#        [-0.26304438,  0.08792125],
#        [-1.49058483,  0.36145402],
#        [ 1.53105319, -1.31013515],
#        [-0.26304438, -0.58071442],
#        [ 0.6812175 , -1.43170527],
#        [-0.9240277 , -0.30718165],
#        [ 0.87006988, -1.18856502],
#        [-0.64074913, -0.09443393],
#        [ 1.05892225, -0.91503225],
#        [ 0.02023418,  0.05752872],
#        [ 0.77564369,  1.45558511],
#        [-0.26304438, -0.42875177],
#        [ 0.96449606, -1.09738743],
#        [ 0.02023418,  0.05752872],
#        [ 0.77564369, -0.30718165],
#        [ 0.02023418, -0.55032189],
#        [ 1.62547938,  1.69872535],
#        [-0.26304438, -0.24639659],
#        [-1.11288007, -1.12777996],
#        [-1.6794372 ,  0.14870631],
#        [-0.82960151,  0.33106149],
#        [ 0.6812175 , -1.12777996],
#        [ 1.34220082,  0.63498679],
#        [-0.26304438,  0.66537932],
#        [-0.26304438, -0.36796671],
#        [ 0.30351275, -0.51992936],
#        [ 1.24777463,  2.33696849],
#        [-0.074192  ,  0.17909884],
#        [ 0.6812175 , -1.31013515],
#        [-0.26304438, -0.12482646],
#        [ 0.30351275, -1.18856502],
#        [-0.64074913,  0.20949137],
#        [-1.77386339, -1.4620978 ],
#        [-0.074192  ,  0.2398839 ],
#        [ 0.6812175 , -1.43170527],
#        [-0.26304438, -0.67189201],
#        [-0.16861819,  1.48597764],
#        [ 0.49236512,  1.82029548],
#        [-1.39615864, -0.18561152],
#        [-0.45189676, -0.55032189],
#        [ 1.81433176, -1.09738743],
#        [ 0.30351275,  0.08792125],
#        [ 1.43662701,  1.06048222],
#        [-0.074192  ,  0.27027643],
#        [ 1.71990557, -0.27678912],
#        [-1.30173245, -0.42875177],
#        [ 0.87006988, -0.79346213],
#        [ 0.30351275, -0.18561152],
#        [-1.39615864, -1.49249033],
#        [ 0.11466037, -0.82385466],
#        [-0.45189676, -0.79346213],
#        [-1.01845389, -1.15817249],
#        [ 0.96449606,  2.09382825],
#        [-1.58501102,  0.57420173],
#        [-1.01845389,  0.45263161],
#        [-0.64074913,  0.05752872],
#        [ 0.02023418, -0.42875177],
#        [-0.73517532,  2.00265066],
#        [-0.074192  , -0.48953683],
#        [ 0.39793894, -0.4591443 ],
#        [ 0.30351275,  0.33106149],
#        [-1.01845389, -1.58366792],
#        [ 0.96449606,  2.18500584],
#        [ 0.87006988, -1.40131274],
#        [-1.11288007, -0.51992936],
#        [ 0.77564369,  0.14870631],
#        [-1.49058483, -0.42875177],
#        [-0.64074913,  0.60459426],
#        [ 0.39793894,  0.30066896],
#        [-0.9240277 , -0.7630696 ],
#        [ 1.05892225,  2.18500584],
#        [-0.73517532, -1.58366792],
#        [ 0.20908656,  0.05752872],
#        [-1.6794372 ,  0.39184655],
#        [-0.9240277 , -0.97581731],
#        [ 0.11466037,  0.30066896],
#        [ 0.30351275, -0.30718165],
#        [-1.58501102, -0.03364887],
#        [-0.9240277 ,  1.63794029],
#        [ 0.77564369, -1.43170527],
#        [ 0.11466037,  0.17909884],
#        [ 1.34220082, -0.94542478],
#        [-1.6794372 ,  0.39184655],
#        [ 2.09761032,  0.99969716],
#        [ 1.24777463,  1.97225813],
#        [-0.26304438, -0.94542478],
#        [ 0.02023418, -0.58071442],
#        [-1.20730626, -1.09738743],
#        [ 2.00318413,  0.57420173],
#        [ 1.81433176, -0.27678912],
#        [ 0.20908656, -0.67189201],
#        [ 0.39793894,  2.42814608],
#        [ 1.15334844, -1.00620984],
#        [ 0.87006988, -1.0669949 ],
#        [ 0.02023418,  1.30362246],
#        [-0.16861819, -0.27678912],
#        [-0.16861819, -0.51992936],
#        [-1.77386339, -1.34052768],
#        [ 0.11466037, -0.30718165],
#        [ 0.96449606,  0.14870631],
#        [ 0.39793894,  1.18205234],
#        [-0.16861819, -0.4591443 ],
#        [-0.35747057, -1.34052768],
#        [ 0.02023418, -0.30718165],
#        [ 0.20908656, -0.24639659],
#        [ 1.15334844,  0.57420173],
#        [-0.35747057, -0.79346213],
#        [-0.26304438,  0.84773451],
#        [-0.074192  ,  2.06343572],
#        [ 2.00318413, -0.82385466],
#        [ 2.09761032, -1.0669949 ],
#        [-1.49058483, -0.18561152],
#        [-0.26304438,  0.08792125],
#        [-0.82960151,  0.42223908],
#        [-0.074192  ,  0.72616438],
#        [-0.45189676,  1.33401499],
#        [-1.39615864,  0.39184655],
#        [-0.074192  , -0.51992936],
#        [-1.49058483, -1.55327539],
#        [ 0.30351275,  0.05752872],
#        [ 0.87006988, -0.61110695],
#        [-0.82960151, -0.79346213],
#        [ 0.96449606, -1.21895755],
#        [-0.26304438, -0.30718165],
#        [ 1.81433176, -1.31013515],
#        [-0.82960151, -0.24639659],
#        [-0.9240277 ,  0.45263161],
#        [-0.26304438, -0.48953683],
#        [ 0.30351275,  0.5438092 ],
#        [ 1.81433176,  0.14870631],
#        [ 0.20908656,  2.21539837],
#        [ 1.71990557,  1.9418656 ],
#        [ 0.39793894,  0.11831378],
#        [-1.30173245, -0.42875177],
#        [-1.11288007,  0.08792125],
#        [ 2.00318413,  0.20949137],
#        [ 1.24777463, -1.40131274],
#        [ 0.39793894,  0.17909884],
#        [ 1.05892225, -1.24935009],
#        [ 1.05892225,  0.60459426],
#        [-1.01845389,  2.06343572],
#        [ 0.6812175 ,  0.30066896],
#        [ 0.11466037,  1.12126728],
#        [-0.73517532,  0.33106149],
#        [-0.82960151, -0.67189201],
#        [-1.11288007, -1.64445298],
#        [ 0.58679131, -0.91503225],
#        [-1.86828958, -0.7630696 ],
#        [ 0.11466037,  0.05752872],
#        [-1.11288007, -0.79346213],
#        [ 1.62547938, -0.91503225],
#        [-1.30173245, -1.52288286],
#        [ 1.62547938,  1.85068801],
#        [-0.45189676, -0.27678912],
#        [-0.64074913, -0.33757418],
#        [-0.9240277 , -1.12777996],
#        [-0.35747057, -0.79346213],
#        [-0.074192  , -1.09738743],
#        [-1.6794372 , -1.00620984],
#        [-1.11288007, -1.03660237],
#        [-1.11288007,  1.48597764],
#        [-0.074192  , -0.21600405],
#        [ 1.90875795,  2.27618343],
#        [-1.20730626,  0.5438092 ],
#        [-0.9240277 , -0.30718165],
#        [-0.26304438, -0.58071442],
#        [ 0.20908656, -0.36796671],
#        [ 0.11466037, -0.82385466],
#        [-1.86828958,  0.51341667],
#        [-1.30173245, -1.27974262],
#        [ 1.34220082,  2.45853861],
#        [ 0.02023418,  0.33106149],
#        [-1.77386339,  0.20949137],
#        [-1.11288007,  0.45263161],
#        [ 0.58679131,  2.12422078],
#        [-0.26304438, -1.27974262],
#        [-1.77386339, -1.52288286],
#        [-1.86828958,  0.39184655],
#        [-0.54632295, -1.55327539],
#        [ 0.20908656,  0.08792125],
#        [-0.26304438, -1.49249033],
#        [ 0.11466037,  1.97225813],
#        [-0.64074913, -1.0669949 ],
#        [-0.54632295,  1.5467627 ],
#        [-0.45189676,  2.42814608],
#        [ 0.87006988, -1.34052768],
#        [ 1.90875795,  0.96930463],
#        [-1.11288007,  0.36145402],
#        [ 0.30351275, -0.55032189],
#        [-0.26304438,  0.2398839 ],
#        [-0.64074913,  0.14870631],
#        [ 0.20908656, -0.30718165],
#        [-1.86828958, -0.51992936],
#        [-0.9240277 ,  0.48302414],
#        [ 0.49236512,  1.9418656 ],
#        [-1.6794372 , -0.61110695],
#        [ 0.96449606,  1.88108054],
#        [-1.11288007,  0.33106149],
#        [ 0.30351275,  0.08792125],
#        [ 0.87006988,  1.33401499],
#        [ 0.02023418,  1.33401499],
#        [ 0.11466037,  0.11831378],
#        [ 0.11466037,  0.81734198],
#        [ 0.49236512,  1.30362246],
#        [-1.58501102,  0.08792125],
#        [ 1.05892225,  0.57420173],
#        [-0.16861819, -0.18561152],
#        [ 1.05892225, -0.12482646],
#        [-0.35747057,  1.30362246],
#        [-0.9240277 ,  0.30066896],
#        [-0.82960151,  0.42223908],
#        [-1.01845389, -0.36796671],
#        [-1.01845389, -0.33757418],
#        [-1.01845389, -1.49249033],
#        [ 1.15334844, -0.7630696 ],
#        [-1.01845389,  0.63498679],
#        [-1.20730626,  0.30066896],
#        [-0.26304438, -1.34052768],
#        [ 0.11466037,  1.60754776],
#        [-1.11288007, -1.61406045],
#        [-1.30173245, -0.33757418],
#        [-0.26304438, -0.7630696 ],
#        [ 0.96449606,  0.63498679],
#        [ 0.30351275, -0.51992936]])

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
X_test_scaled
# Out:
#           Age  EstimatedSalary
# 0    2.097610         1.182052
# 1   -0.263044        -0.915032
# 2    0.870070         2.276183
# 3   -0.735175         0.604594
# 4   -0.735175        -0.611107
# ..        ...              ...
# 115  0.303513         0.087921
# 116 -1.396159        -0.641499
# 117  0.775644        -0.854247
# 118 -0.074192         2.336968
# 119 -0.640749        -0.033649
#
# [120 rows x 2 columns]

# %%
X_train_scaled
# Out:
#           Age  EstimatedSalary
# 0   -0.546323         0.513417
# 1    1.058922         0.148706
# 2   -0.263044         0.057529
# 3    2.097610         0.422239
# 4    0.303513        -0.732677
# ..        ...              ...
# 275 -1.112880        -1.614060
# 276 -1.301732        -0.337574
# 277 -0.263044        -0.763070
# 278  0.964496         0.634987
# 279  0.303513        -0.519929
#
# [280 rows x 2 columns]

# %%
np.round(X_train_scaled.describe(), 1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.1              0.0
# 75%      0.8              0.5
# max      2.2              2.3

# %%
np.round(X_test_scaled.describe(), 1)
# Out:
#          Age  EstimatedSalary
# count  120.0            120.0
# mean    -0.0              0.1
# std      1.0              1.1
# min     -1.9             -1.6
# 25%     -0.7             -0.9
# 50%     -0.2              0.1
# 75%      0.8              0.6
# max      2.1              2.4

# %% [markdown]
# # Effect of Scaling

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Age'], X_train_scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Age'], ax=ax1)
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)

# after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(X_train_scaled['Age'], ax=ax2)
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2)
plt.show()

# %% [markdown]
# # Comparison of Distributions

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Age Distribution Before Scaling')
sns.kdeplot(X_train['Age'], ax=ax1)

# after scaling
ax2.set_title('Age Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Age'], ax=ax2)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Salary Distribution Before Scaling')
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)

# after scaling
ax2.set_title('Salary Distribution Standard Scaling')
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2)
plt.show()

# %% [markdown]
# # Why scaling is important?

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr_scaled = LogisticRegression()

# %%
lr.fit(X_train,y_train)
lr_scaled.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)
y_pred_scaled = lr_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual 0.6166666666666667
# Scaled 0.8166666666666667

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
dt_scaled.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)
y_pred_scaled = dt_scaled.predict(X_test_scaled)

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual 0.8916666666666667
# Scaled 0.8916666666666667

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %%
# only linear model requires scaling

# outlier will not change by sc
